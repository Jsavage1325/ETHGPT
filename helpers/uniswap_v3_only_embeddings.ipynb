# %%
import os
from langchain.document_loaders import ReadTheDocsLoader, GitbookLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from config import OPENAI_API_KEY
import subprocess

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
loader = GitbookLoader('https://docs.uniswap.org/', load_all_paths=True)

# %%
raw_documents = loader.load()
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 750,chunk_overlap  = 125,length_function = len)
documents = text_splitter.split_documents(raw_documents)
# Out:
# Fetching text from https://docs.uniswap.org/blog
# Fetching text from https://docs.uniswap.org/blog/archive
# Fetching text from https://docs.uniswap.org/blog/intro-to-gas-optimization
# Fetching text from https://docs.uniswap.org/search
# Fetching text from https://docs.uniswap.org/
# Fetching text from https://docs.uniswap.org/api/subgraph/guides/examples
# Fetching text from https://docs.uniswap.org/api/subgraph/overview
# Fetching text from https://docs.uniswap.org/concepts/glossary
# Fetching text from https://docs.uniswap.org/concepts/governance/adversarial-circumstances
# Fetching text from https://docs.uniswap.org/concepts/governance/changelog
# Fetching text from https://docs.uniswap.org/concepts/governance/glossary
# Fetching text from https://docs.uniswap.org/concepts/governance/guide-to-voting
# Fetching text from https://docs.uniswap.org/concepts/governance/overview
# Fetching text from https://docs.uniswap.org/concepts/governance/process
# Fetching text from https://docs.uniswap.org/concepts/overview
# Fetching text from https://docs.uniswap.org/concepts/protocol/concentrated-liquidity
# Fetching text from https://docs.uniswap.org/concepts/protocol/fees
# Fetching text from https://docs.uniswap.org/concepts/protocol/integration-issues
# Fetching text from https://docs.uniswap.org/concepts/protocol/oracle
# Fetching text from https://docs.uniswap.org/concepts/protocol/range-orders
# Fetching text from https://docs.uniswap.org/concepts/protocol/swaps
# Fetching text from https://docs.uniswap.org/concepts/research
# Fetching text from https://docs.uniswap.org/concepts/resources
# Fetching text from https://docs.uniswap.org/concepts/uniswap-protocol
# Fetching text from https://docs.uniswap.org/contracts/permit2/overview
# Fetching text from https://docs.uniswap.org/contracts/permit2/reference/allowance-transfer
# Fetching text from https://docs.uniswap.org/contracts/permit2/reference/signature-transfer
# Fetching text from https://docs.uniswap.org/contracts/universal-router/overview
# Fetching text from https://docs.uniswap.org/contracts/universal-router/technical-reference
# Fetching text from https://docs.uniswap.org/contracts/v1/guides/connect-to-uniswap
# Fetching text from https://docs.uniswap.org/contracts/v1/guides/custom-linking
# Fetching text from https://docs.uniswap.org/contracts/v1/guides/iframe-integration
# Fetching text from https://docs.uniswap.org/contracts/v1/guides/pool-liquidity
# Fetching text from https://docs.uniswap.org/contracts/v1/guides/token-listing
# Fetching text from https://docs.uniswap.org/contracts/v1/guides/trade-tokens
# Fetching text from https://docs.uniswap.org/contracts/v1/overview
# Fetching text from https://docs.uniswap.org/contracts/v1/reference/exchange
# Fetching text from https://docs.uniswap.org/contracts/v1/reference/factory
# Fetching text from https://docs.uniswap.org/contracts/v1/reference/interfaces
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/advanced-topics/fees
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/advanced-topics/math
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/advanced-topics/pricing
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/advanced-topics/research
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/advanced-topics/security
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/advanced-topics/understanding-returns
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/core-concepts/flash-swaps
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/core-concepts/oracles
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/core-concepts/pools
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/core-concepts/swaps
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/protocol-overview/ecosystem-participants
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/protocol-overview/glossary
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/protocol-overview/how-uniswap-works
# Fetching text from https://docs.uniswap.org/contracts/v2/concepts/protocol-overview/smart-contracts
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/interface-integration/custom-interface-linking
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/interface-integration/iframe-integration
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/interface-integration/using-the-api
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/building-an-oracle
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/getting-pair-addresses
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/providing-liquidity
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/quick-start
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/supporting-meta-transactions
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/trading-from-a-smart-contract
# Fetching text from https://docs.uniswap.org/contracts/v2/guides/smart-contract-integration/using-flash-swaps
# Fetching text from https://docs.uniswap.org/contracts/v2/overview
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/API/entities
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/API/overview
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/API/queries
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/Governance/governance-reference
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/common-errors
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/factory
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/library
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/pair
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/Pair-ERC-20
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/router-01
# Fetching text from https://docs.uniswap.org/contracts/v2/reference/smart-contracts/router-02
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/flash-integrations/calling-flash
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/flash-integrations/final-contract
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/flash-integrations/flash-callback
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/flash-integrations/inheritance-constructors
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/governance/liscense-modifications
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/liquidity-mining/overview
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/local-environment
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/collect-fees
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/decrease-liquidity
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/increase-liquidity
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/mint-a-position
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/setting-up
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/the-full-contract
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/swaps/multihop-swaps
# Fetching text from https://docs.uniswap.org/contracts/v3/guides/swaps/single-swaps
# Fetching text from https://docs.uniswap.org/contracts/v3/overview
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/callback/IUniswapV3FlashCallback
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/callback/IUniswapV3MintCallback
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/callback/IUniswapV3SwapCallback
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IERC20Minimal
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IUniswapV3Factory
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IUniswapV3Pool
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IUniswapV3PoolDeployer
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolActions
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolDerivedState
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolEvents
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolImmutables
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolOwnerActions
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolState
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/BitMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/FixedPoint128
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/FixedPoint96
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/FullMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/LiquidityMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/LowGasSafeMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/Oracle
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/Position
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/SafeCast
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/SecondsOutside
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/SqrtPriceMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/SwapMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/Tick
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/TickBitmap
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/TickMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/TransferHelper
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/libraries/UnsafeMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/UniswapV3Factory
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/UniswapV3Pool
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/core/UniswapV3PoolDeployer
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/deployments
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/error-codes
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/governance/overview
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/overview
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/BlockTimestamp
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/ERC721Permit
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/LiquidityManagement
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/Multicall
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/PeripheryImmutableState
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/PeripheryPayments
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/PeripheryPaymentsWithFee
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/PoolInitializer
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/base/SelfPermit
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/external/IERC1271
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/external/IERC20PermitAllowed
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/external/IWETH9
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IERC20Metadata
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IERC721Permit
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IMulticall
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/INonfungiblePositionManager
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/INonfungibleTokenPositionDescriptor
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPeripheryImmutableState
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPeripheryPayments
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPeripheryPaymentsWithFee
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPoolInitializer
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IQuoter
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IQuoterV2
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/ISelfPermit
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/ISwapRouter
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/ITickLens
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IV3Migrator
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/lens/Quoter
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/lens/QuoterV2
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/lens/TickLens
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/Base64
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/BytesLib
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/CallbackValidation
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/ChainId
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/HexStrings
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/LiquidityAmounts
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/NFTDescriptor
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/NFTSVG
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/OracleLibrary
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/Path
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/PoolAddress
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/PoolTicksCounter
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/PositionKey
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/TokenRatioSortOrder
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/TransferHelper
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/WeightedOracleLibrary
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/NonfungiblePositionManager
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/NonfungibleTokenPositionDescriptor
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/staker/Design
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/staker/interfaces/IUniswapV3Staker
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/staker/libraries/IncentiveId
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/staker/libraries/NFTPositionInfo
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/staker/libraries/RewardMath
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/staker/UniswapV3Staker
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/SwapRouter
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/Base64Test
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/LiquidityAmountsTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/MockTimeNonfungiblePositionManager
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/MockTimeSwapRouter
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/NFTDescriptorTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/PathTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/PeripheryImmutableStateTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/PoolAddressTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/SelfPermitTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestCallbackValidation
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestERC20
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestERC20Metadata
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestERC20PermitAllowed
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestMulticall
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestPositionNFTOwner
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestUniswapV3Callee
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/test/TickLensTest
# Fetching text from https://docs.uniswap.org/contracts/v3/reference/periphery/V3Migrator
# Fetching text from https://docs.uniswap.org/sdk/core/overview
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/CurrencyAmount
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/Ether
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/Fraction
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/NativeCurrency
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/Percent
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/Price
# Fetching text from https://docs.uniswap.org/sdk/core/reference/classes/Token
# Fetching text from https://docs.uniswap.org/sdk/core/reference/enums/Rounding
# Fetching text from https://docs.uniswap.org/sdk/core/reference/enums/SupportedChainId
# Fetching text from https://docs.uniswap.org/sdk/core/reference/enums/TradeType
# Fetching text from https://docs.uniswap.org/sdk/core/reference/overview
# Fetching text from https://docs.uniswap.org/sdk/swap-widget/guides/examples
# Fetching text from https://docs.uniswap.org/sdk/swap-widget/guides/getting-started
# Fetching text from https://docs.uniswap.org/sdk/swap-widget/overview
# Fetching text from https://docs.uniswap.org/sdk/swap-widget/reference/v1
# Fetching text from https://docs.uniswap.org/sdk/swap-widget/reference/v2
# Fetching text from https://docs.uniswap.org/sdk/v1/guides/getting-started
# Fetching text from https://docs.uniswap.org/sdk/v1/overview
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/computation
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/constants
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/data
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/format
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/orchestration
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/transact
# Fetching text from https://docs.uniswap.org/sdk/v1/reference/types
# Fetching text from https://docs.uniswap.org/sdk/v2/guides/fetching-data
# Fetching text from https://docs.uniswap.org/sdk/v2/guides/getting-pair-addresses
# Fetching text from https://docs.uniswap.org/sdk/v2/guides/pricing
# Fetching text from https://docs.uniswap.org/sdk/v2/guides/quick-start
# Fetching text from https://docs.uniswap.org/sdk/v2/guides/trading
# Fetching text from https://docs.uniswap.org/sdk/v2/overview
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/fetcher
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/fractions
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/getting-started
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/other-exports
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/pair
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/route
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/token
# Fetching text from https://docs.uniswap.org/sdk/v2/reference/trade
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/background
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/liquidity/liquidity-fees
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/liquidity/minting
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/liquidity/modifying-position
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/liquidity/swap-and-add
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/quoting
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/routing
# Fetching text from https://docs.uniswap.org/sdk/v3/guides/trading
# Fetching text from https://docs.uniswap.org/sdk/v3/overview
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/FullMath
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/LiquidityMath
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Multicall
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/NonfungiblePositionManager
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/NoTickDataProvider
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Payments
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Pool
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Position
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/PositionLibrary
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Route
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/SelfPermit
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/SqrtPriceMath
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Staker
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/SwapMath
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/SwapQuoter
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/SwapRouter
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Tick
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/TickLibrary
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/TickList
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/TickListDataProvider
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/TickMath
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/classes/Trade
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/enums/FeeAmount
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/AllowedPermitArguments
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/BestTradeOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/ClaimOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/CollectOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/CommonAddLiquidityOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/FeeOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/IncentiveKey
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/IncreaseSpecificOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/MethodParameters
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/MintSpecificOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/NFTPermitOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/QuoteOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/RemoveLiquidityOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/SafeTransferOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/StandardPermitArguments
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/SwapOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/TickConstructorArgs
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/TickDataProvider
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/interfaces/WithdrawOptions
# Fetching text from https://docs.uniswap.org/sdk/v3/reference/overview
# Fetching text from https://docs.uniswap.org/sdk/web3-react/guides/connect-wallet
# Fetching text from https://docs.uniswap.org/sdk/web3-react/guides/connectors
# Fetching text from https://docs.uniswap.org/sdk/web3-react/guides/switch-chains
# Fetching text from https://docs.uniswap.org/sdk/web3-react/overview

# %%
##remove V1 and V2 docs
len1 = len(documents)
source = []
for i in documents:
    if '/v2' in i.metadata['source']:
        documents.remove(i)
    elif '/v1' in i.metadata['source']:
        documents.remove(i)
    else:
        source.append(i.metadata['source'])


len2 = len(documents)

##how many docs were removed
print(len1-len2)
# Out:
# 310

# %%
##print unique elements in source
import numpy as np 
print(np.unique(source))
# Out:
# ['https://docs.uniswap.org/api/subgraph/guides/examples'
#  'https://docs.uniswap.org/api/subgraph/overview'
#  'https://docs.uniswap.org/blog' 'https://docs.uniswap.org/blog/archive'
#  'https://docs.uniswap.org/blog/intro-to-gas-optimization'
#  'https://docs.uniswap.org/concepts/glossary'
#  'https://docs.uniswap.org/concepts/governance/adversarial-circumstances'
#  'https://docs.uniswap.org/concepts/governance/changelog'
#  'https://docs.uniswap.org/concepts/governance/glossary'
#  'https://docs.uniswap.org/concepts/governance/guide-to-voting'
#  'https://docs.uniswap.org/concepts/governance/overview'
#  'https://docs.uniswap.org/concepts/governance/process'
#  'https://docs.uniswap.org/concepts/overview'
#  'https://docs.uniswap.org/concepts/protocol/concentrated-liquidity'
#  'https://docs.uniswap.org/concepts/protocol/fees'
#  'https://docs.uniswap.org/concepts/protocol/integration-issues'
#  'https://docs.uniswap.org/concepts/protocol/oracle'
#  'https://docs.uniswap.org/concepts/protocol/range-orders'
#  'https://docs.uniswap.org/concepts/protocol/swaps'
#  'https://docs.uniswap.org/concepts/research'
#  'https://docs.uniswap.org/concepts/resources'
#  'https://docs.uniswap.org/concepts/uniswap-protocol'
#  'https://docs.uniswap.org/contracts/permit2/overview'
#  'https://docs.uniswap.org/contracts/permit2/reference/allowance-transfer'
#  'https://docs.uniswap.org/contracts/permit2/reference/signature-transfer'
#  'https://docs.uniswap.org/contracts/universal-router/overview'
#  'https://docs.uniswap.org/contracts/universal-router/technical-reference'
#  'https://docs.uniswap.org/contracts/v3/guides/flash-integrations/calling-flash'
#  'https://docs.uniswap.org/contracts/v3/guides/flash-integrations/final-contract'
#  'https://docs.uniswap.org/contracts/v3/guides/flash-integrations/flash-callback'
#  'https://docs.uniswap.org/contracts/v3/guides/flash-integrations/inheritance-constructors'
#  'https://docs.uniswap.org/contracts/v3/guides/governance/liscense-modifications'
#  'https://docs.uniswap.org/contracts/v3/guides/liquidity-mining/overview'
#  'https://docs.uniswap.org/contracts/v3/guides/local-environment'
#  'https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/collect-fees'
#  'https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/decrease-liquidity'
#  'https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/increase-liquidity'
#  'https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/mint-a-position'
#  'https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/setting-up'
#  'https://docs.uniswap.org/contracts/v3/guides/providing-liquidity/the-full-contract'
#  'https://docs.uniswap.org/contracts/v3/guides/swaps/multihop-swaps'
#  'https://docs.uniswap.org/contracts/v3/guides/swaps/single-swaps'
#  'https://docs.uniswap.org/contracts/v3/overview'
#  'https://docs.uniswap.org/contracts/v3/reference/core/UniswapV3Factory'
#  'https://docs.uniswap.org/contracts/v3/reference/core/UniswapV3Pool'
#  'https://docs.uniswap.org/contracts/v3/reference/core/UniswapV3PoolDeployer'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IERC20Minimal'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IUniswapV3Factory'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IUniswapV3Pool'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/IUniswapV3PoolDeployer'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/callback/IUniswapV3FlashCallback'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/callback/IUniswapV3MintCallback'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/callback/IUniswapV3SwapCallback'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolActions'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolDerivedState'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolEvents'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolImmutables'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolOwnerActions'
#  'https://docs.uniswap.org/contracts/v3/reference/core/interfaces/pool/IUniswapV3PoolState'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/BitMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/FixedPoint128'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/FixedPoint96'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/FullMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/LiquidityMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/LowGasSafeMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/Oracle'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/Position'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/SafeCast'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/SecondsOutside'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/SqrtPriceMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/SwapMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/Tick'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/TickBitmap'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/TickMath'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/TransferHelper'
#  'https://docs.uniswap.org/contracts/v3/reference/core/libraries/UnsafeMath'
#  'https://docs.uniswap.org/contracts/v3/reference/deployments'
#  'https://docs.uniswap.org/contracts/v3/reference/error-codes'
#  'https://docs.uniswap.org/contracts/v3/reference/governance/overview'
#  'https://docs.uniswap.org/contracts/v3/reference/overview'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/NonfungiblePositionManager'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/NonfungibleTokenPositionDescriptor'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/SwapRouter'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/V3Migrator'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/BlockTimestamp'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/ERC721Permit'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/LiquidityManagement'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/Multicall'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/PeripheryImmutableState'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/PeripheryPayments'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/PeripheryPaymentsWithFee'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/PoolInitializer'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/base/SelfPermit'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IERC20Metadata'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IERC721Permit'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IMulticall'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/INonfungiblePositionManager'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/INonfungibleTokenPositionDescriptor'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPeripheryImmutableState'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPeripheryPayments'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPeripheryPaymentsWithFee'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IPoolInitializer'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IQuoter'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IQuoterV2'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/ISelfPermit'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/ISwapRouter'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/ITickLens'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/IV3Migrator'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/external/IERC1271'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/external/IERC20PermitAllowed'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/interfaces/external/IWETH9'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/lens/Quoter'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/lens/QuoterV2'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/lens/TickLens'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/Base64'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/BytesLib'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/CallbackValidation'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/ChainId'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/HexStrings'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/LiquidityAmounts'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/NFTDescriptor'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/NFTSVG'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/OracleLibrary'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/Path'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/PoolAddress'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/PoolTicksCounter'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/PositionKey'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/TokenRatioSortOrder'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/TransferHelper'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/libraries/WeightedOracleLibrary'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/staker/Design'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/staker/UniswapV3Staker'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/staker/interfaces/IUniswapV3Staker'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/staker/libraries/IncentiveId'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/staker/libraries/NFTPositionInfo'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/staker/libraries/RewardMath'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/Base64Test'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/LiquidityAmountsTest'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/MockTimeNonfungiblePositionManager'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/MockTimeSwapRouter'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/NFTDescriptorTest'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/PathTest'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/PeripheryImmutableStateTest'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/PoolAddressTest'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/SelfPermitTest'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestCallbackValidation'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestERC20'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestERC20Metadata'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestERC20PermitAllowed'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestMulticall'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestPositionNFTOwner'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TestUniswapV3Callee'
#  'https://docs.uniswap.org/contracts/v3/reference/periphery/test/TickLensTest'
#  'https://docs.uniswap.org/sdk/core/overview'
#  'https://docs.uniswap.org/sdk/core/reference/classes/CurrencyAmount'
#  'https://docs.uniswap.org/sdk/core/reference/classes/Ether'
#  'https://docs.uniswap.org/sdk/core/reference/classes/Fraction'
#  'https://docs.uniswap.org/sdk/core/reference/classes/NativeCurrency'
#  'https://docs.uniswap.org/sdk/core/reference/classes/Percent'
#  'https://docs.uniswap.org/sdk/core/reference/classes/Price'
#  'https://docs.uniswap.org/sdk/core/reference/classes/Token'
#  'https://docs.uniswap.org/sdk/core/reference/enums/Rounding'
#  'https://docs.uniswap.org/sdk/core/reference/enums/SupportedChainId'
#  'https://docs.uniswap.org/sdk/core/reference/enums/TradeType'
#  'https://docs.uniswap.org/sdk/core/reference/overview'
#  'https://docs.uniswap.org/sdk/swap-widget/guides/examples'
#  'https://docs.uniswap.org/sdk/swap-widget/guides/getting-started'
#  'https://docs.uniswap.org/sdk/swap-widget/overview'
#  'https://docs.uniswap.org/sdk/v3/guides/background'
#  'https://docs.uniswap.org/sdk/v3/guides/liquidity/liquidity-fees'
#  'https://docs.uniswap.org/sdk/v3/guides/liquidity/minting'
#  'https://docs.uniswap.org/sdk/v3/guides/liquidity/modifying-position'
#  'https://docs.uniswap.org/sdk/v3/guides/liquidity/swap-and-add'
#  'https://docs.uniswap.org/sdk/v3/guides/quoting'
#  'https://docs.uniswap.org/sdk/v3/guides/routing'
#  'https://docs.uniswap.org/sdk/v3/guides/trading'
#  'https://docs.uniswap.org/sdk/v3/overview'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/FullMath'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/LiquidityMath'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Multicall'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/NoTickDataProvider'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/NonfungiblePositionManager'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Payments'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Pool'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Position'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/PositionLibrary'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Route'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/SelfPermit'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/SqrtPriceMath'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Staker'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/SwapMath'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/SwapQuoter'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/SwapRouter'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Tick'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/TickLibrary'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/TickList'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/TickListDataProvider'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/TickMath'
#  'https://docs.uniswap.org/sdk/v3/reference/classes/Trade'
#  'https://docs.uniswap.org/sdk/v3/reference/enums/FeeAmount'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/AllowedPermitArguments'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/BestTradeOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/ClaimOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/CollectOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/CommonAddLiquidityOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/FeeOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/IncentiveKey'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/IncreaseSpecificOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/MethodParameters'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/MintSpecificOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/NFTPermitOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/QuoteOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/RemoveLiquidityOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/SafeTransferOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/StandardPermitArguments'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/SwapOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/TickConstructorArgs'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/TickDataProvider'
#  'https://docs.uniswap.org/sdk/v3/reference/interfaces/WithdrawOptions'
#  'https://docs.uniswap.org/sdk/v3/reference/overview'
#  'https://docs.uniswap.org/sdk/web3-react/guides/connect-wallet'
#  'https://docs.uniswap.org/sdk/web3-react/guides/connectors'
#  'https://docs.uniswap.org/sdk/web3-react/guides/switch-chains'
#  'https://docs.uniswap.org/sdk/web3-react/overview']

# %%
##embed remaining docs to vectorstore
embeddings = OpenAIEmbeddings()

vectorstore = FAISS.from_documents(documents, embeddings)

# %%
query = "What is UNIswap?"
docs = vectorstore.similarity_search(query)
print(docs[0].page_content)
# Out:
# Funded through an
# Ethereum Foundation grant
# Resources
# Website
# GitHub
# Twitter
# Reddit
# Email
# Whitepaper
# How it works
# Uniswap is made up of a series of ETH-ERC20 exchange contracts. There is exactly one exchange contract per ERC20 token. If a token does not yet have an exchange it can be created by anyone using the Uniswap factory contract. The factory serves as a public registry and is used to look up all token and exchange addresses added to the system.

# %%
#save to local file
vectorstore.save_local(f"uniswap_v3_faiss_index")
